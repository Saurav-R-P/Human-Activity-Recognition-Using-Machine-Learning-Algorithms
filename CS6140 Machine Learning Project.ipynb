# %%
#importing all necessary libraries and packages
import numpy as np
import pandas as pd
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from sklearn.manifold import TSNE

# %%
#now, we will get the featured-engineered features from the file features.txt
features = list()
with open('UCI HAR Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %%
#now, we will get the data from txt files into pandas data frame
X_train = pd.read_csv('UCI HAR Dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = [features]

#now, we will add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI HAR Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI HAR Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

#now, we will put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 224           0.282021         -0.017590         -0.107934        -0.995237
# 6713          0.276017         -0.017467         -0.112640        -0.992656
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 224         -0.996592        -0.995152        -0.995527        -0.996552
# 6713        -0.993759        -0.992550        -0.994374        -0.993272
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 224         -0.995840        -0.940793  ...                   -0.092317
# 6713        -0.992711        -0.933982  ...                    0.483526
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 224                              0.171126                        -0.893619
# 6713                            -0.100026                        -0.669600
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 224                              0.825290             0.276459
# 6713                            -0.087032             0.467852
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity ActivityName
# 224             -0.577464            -0.350428       1        6       LAYING
# 6713            -0.565518            -0.427502      29        6       LAYING
#
# [2 rows x 564 columns]

# %%
#now, we will get the data from txt files to pandas data frame
X_test = pd.read_csv('UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = [features]
#now, we will add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI HAR Dataset/test/subject_test.txt', header=None, squeeze=True)

#now, we will get y labels from the txt file
y_test = pd.read_csv('UCI HAR Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


#now we will put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample(2)
# Out:
#      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 1443          0.274059         -0.020362         -0.131241        -0.994011
# 409           0.272434         -0.021555         -0.129240        -0.483910
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 1443        -0.989675        -0.985977        -0.994515        -0.990812
# 409         -0.015636        -0.535280        -0.504506        -0.036967
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 1443        -0.986981        -0.937607  ...                    0.009643
# 409         -0.522606        -0.382798  ...                    0.155234
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 1443                             0.307975                         0.551995
# 409                              0.062255                        -0.827045
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 1443                             0.698333             0.529103
# 409                              0.162210            -0.837710
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity ActivityName
# 1443            -0.844710             0.177955      12        6       LAYING
# 409              0.166456            -0.075336       4        1      WALKING
#
# [2 rows x 564 columns]

# %%
train.head
# Out:
# <bound method NDFrame.head of      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0             0.288585         -0.020294         -0.132905        -0.995279
# 1             0.278419         -0.016411         -0.123520        -0.998245
# 2             0.279653         -0.019467         -0.113462        -0.995380
# 3             0.279174         -0.026201         -0.123283        -0.996091
# 4             0.276629         -0.016570         -0.115362        -0.998139
# ...                ...               ...               ...              ...
# 7347          0.299665         -0.057193         -0.181233        -0.195387
# 7348          0.273853         -0.007749         -0.147468        -0.235309
# 7349          0.273387         -0.017011         -0.045022        -0.218218
# 7350          0.289654         -0.018843         -0.158281        -0.219139
# 7351          0.351503         -0.012423         -0.203867        -0.269270
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0           -0.983111        -0.913526        -0.995112        -0.983185
# 1           -0.975300        -0.960322        -0.998807        -0.974914
# 2           -0.967187        -0.978944        -0.996520        -0.963668
# 3           -0.983403        -0.990675        -0.997099        -0.982750
# 4           -0.980817        -0.990482        -0.998321        -0.979672
# ...               ...              ...              ...              ...
# 7347         0.039905         0.077078        -0.282301         0.043616
# 7348         0.004816         0.059280        -0.322552        -0.029456
# 7349        -0.103822         0.274533        -0.304515        -0.098913
# 7350        -0.111412         0.268893        -0.310487        -0.068200
# 7351        -0.087212         0.177404        -0.377404        -0.038678
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0           -0.923527        -0.934724  ...                   -0.112754
# 1           -0.957686        -0.943068  ...                    0.053477
# 2           -0.977469        -0.938692  ...                   -0.118559
# 3           -0.989302        -0.938692  ...                   -0.036788
# 4           -0.990441        -0.942469  ...                    0.123320
# ...               ...              ...  ...                         ...
# 7347         0.060410         0.210795  ...                   -0.190437
# 7348         0.080585         0.117440  ...                    0.064907
# 7349         0.332584         0.043999  ...                    0.052806
# 7350         0.319473         0.101702  ...                   -0.101360
# 7351         0.229430         0.269013  ...                   -0.280088
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                                0.030400                        -0.464761
# 1                               -0.007435                        -0.732626
# 2                                0.177899                         0.100699
# 3                               -0.012892                         0.640011
# 4                                0.122542                         0.693578
# ...                                   ...                              ...
# 7347                             0.829718                         0.206972
# 7348                             0.875679                        -0.879033
# 7349                            -0.266724                         0.864404
# 7350                             0.700740                         0.936674
# 7351                            -0.007739                        -0.056088
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                               -0.018446            -0.841247
# 1                                0.703511            -0.844788
# 2                                0.808529            -0.848933
# 3                               -0.485366            -0.848649
# 4                               -0.615971            -0.847865
# ...                                   ...                  ...
# 7347                            -0.425619            -0.791883
# 7348                             0.400219            -0.771840
# 7349                             0.701169            -0.779133
# 7350                            -0.589479            -0.785181
# 7351                            -0.616956            -0.783267
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity  \
# 0                0.179941            -0.058627       1        5
# 1                0.180289            -0.054317       1        5
# 2                0.180637            -0.049118       1        5
# 3                0.181935            -0.047663       1        5
# 4                0.185151            -0.043892       1        5
# ...                   ...                  ...     ...      ...
# 7347             0.238604             0.049819      30        2
# 7348             0.252676             0.050053      30        2
# 7349             0.249145             0.040811      30        2
# 7350             0.246432             0.025339      30        2
# 7351             0.246809             0.036695      30        2
#
#           ActivityName
# 0             STANDING
# 1             STANDING
# 2             STANDING
# 3             STANDING
# 4             STANDING
# ...                ...
# 7347  WALKING_UPSTAIRS
# 7348  WALKING_UPSTAIRS
# 7349  WALKING_UPSTAIRS
# 7350  WALKING_UPSTAIRS
# 7351  WALKING_UPSTAIRS
#
# [7352 rows x 564 columns]>

# %%
test.head
# Out:
# <bound method NDFrame.head of      tBodyAcc-mean()-X tBodyAcc-mean()-Y tBodyAcc-mean()-Z tBodyAcc-std()-X  \
# 0             0.257178         -0.023285         -0.014654        -0.938404
# 1             0.286027         -0.013163         -0.119083        -0.975415
# 2             0.275485         -0.026050         -0.118152        -0.993819
# 3             0.270298         -0.032614         -0.117520        -0.994743
# 4             0.274833         -0.027848         -0.129527        -0.993852
# ...                ...               ...               ...              ...
# 2942          0.310155         -0.053391         -0.099109        -0.287866
# 2943          0.363385         -0.039214         -0.105915        -0.305388
# 2944          0.349966          0.030077         -0.115788        -0.329638
# 2945          0.237594          0.018467         -0.096499        -0.323114
# 2946          0.153627         -0.018437         -0.137018        -0.330046
#
#      tBodyAcc-std()-Y tBodyAcc-std()-Z tBodyAcc-mad()-X tBodyAcc-mad()-Y  \
# 0           -0.920091        -0.667683        -0.952501        -0.925249
# 1           -0.967458        -0.944958        -0.986799        -0.968401
# 2           -0.969926        -0.962748        -0.994403        -0.970735
# 3           -0.973268        -0.967091        -0.995274        -0.974471
# 4           -0.967445        -0.978295        -0.994111        -0.965953
# ...               ...              ...              ...              ...
# 2942        -0.140589        -0.215088        -0.356083        -0.148775
# 2943         0.028148        -0.196373        -0.373540        -0.030036
# 2944        -0.042143        -0.250181        -0.388017        -0.133257
# 2945        -0.229775        -0.207574        -0.392380        -0.279610
# 2946        -0.195253        -0.164339        -0.430974        -0.218295
#
#      tBodyAcc-mad()-Z tBodyAcc-max()-X  ... angle(tBodyAccMean,gravity)  \
# 0           -0.674302        -0.894088  ...                    0.006462
# 1           -0.945823        -0.894088  ...                   -0.083495
# 2           -0.963483        -0.939260  ...                   -0.034956
# 3           -0.968897        -0.938610  ...                   -0.017067
# 4           -0.977346        -0.938610  ...                   -0.002223
# ...               ...              ...  ...                         ...
# 2942        -0.232057         0.185361  ...                   -0.337422
# 2943        -0.270237         0.185361  ...                   -0.736701
# 2944        -0.347029         0.007471  ...                   -0.181560
# 2945        -0.289477         0.007471  ...                    0.444558
# 2946        -0.229933        -0.111527  ...                    0.598808
#
#      angle(tBodyAccJerkMean),gravityMean) angle(tBodyGyroMean,gravityMean)  \
# 0                                0.162920                        -0.825886
# 1                                0.017500                        -0.434375
# 2                                0.202302                         0.064103
# 3                                0.154438                         0.340134
# 4                               -0.040046                         0.736715
# ...                                   ...                              ...
# 2942                             0.346295                         0.884904
# 2943                            -0.372889                        -0.657421
# 2944                             0.088574                         0.696663
# 2945                            -0.819188                         0.929294
# 2946                            -0.287951                         0.876030
#
#      angle(tBodyGyroJerkMean,gravityMean) angle(X,gravityMean)  \
# 0                                0.271151            -0.720009
# 1                                0.920593            -0.698091
# 2                                0.145068            -0.702771
# 3                                0.296407            -0.698954
# 4                               -0.118545            -0.692245
# ...                                   ...                  ...
# 2942                            -0.698885            -0.651732
# 2943                             0.322549            -0.655181
# 2944                             0.363139            -0.655357
# 2945                            -0.008398            -0.659719
# 2946                            -0.024965            -0.660080
#
#      angle(Y,gravityMean) angle(Z,gravityMean) subject Activity  \
# 0                0.276801            -0.057978       2        5
# 1                0.281343            -0.083898       2        5
# 2                0.280083            -0.079346       2        5
# 3                0.284114            -0.077108       2        5
# 4                0.290722            -0.073857       2        5
# ...                   ...                  ...     ...      ...
# 2942             0.274627             0.184784      24        2
# 2943             0.273578             0.182412      24        2
# 2944             0.274479             0.181184      24        2
# 2945             0.264782             0.187563      24        2
# 2946             0.263936             0.188103      24        2
#
#           ActivityName
# 0             STANDING
# 1             STANDING
# 2             STANDING
# 3             STANDING
# 4             STANDING
# ...                ...
# 2942  WALKING_UPSTAIRS
# 2943  WALKING_UPSTAIRS
# 2944  WALKING_UPSTAIRS
# 2945  WALKING_UPSTAIRS
# 2946  WALKING_UPSTAIRS
#
# [2947 rows x 564 columns]>

# %%
train.shape
# Out:
# (7352, 564)

# %%
test.shape
# Out:
# (2947, 564)

# %%
#we will check for duplicates
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# C:\Users\spale\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:2940: PerformanceWarning:
#
# indexing past lexsort depth may impact performance.
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
#we will check for nan/null values
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %%
#we will save test train split into csv files
train.to_csv('UCI HAR Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI HAR Dataset/csv_files/test.csv', index=False)

# %%
#we will now look at shape and head of our test/train files
train = pd.read_csv('UCI HAR Dataset/csv_files/train.csv')
test = pd.read_csv('UCI HAR Dataset/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
#some pre-processing
columns = train.columns

#Removing unnecessary '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# <ipython-input-14-a20d1561f761>:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# <ipython-input-14-a20d1561f761>:6: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# <ipython-input-14-a20d1561f761>:7: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
#using matplotlib and seaborn, we will plot the count of activity of all individuals
sns.set_style('darkgrid')
plt.rcParams['font.family'] = 'Tahoma'

plt.figure(figsize=(16,8))
plt.title('Sensor Data Provided by Individual', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %%
#now we will plot the the count of activities
label_counts = train['ActivityName'].value_counts()

#getting colors
n = label_counts.shape[0]
colormap = plt.get_cmap('viridis')
colors = [mlt.colors.to_hex(colormap(col)) for col in np.arange(0, 1.01, 1/(n-1))]

#creating plot
data = go.Bar(x = label_counts.index,
              y = label_counts,
              marker = dict(color = colors))

layout = go.Layout(title = 'Individual Activity Distribution',
                   xaxis = dict(title = 'ActivityName'),
                   yaxis = dict(title = 'Count'))

fig = go.Figure(data=[data], layout=layout)
fig.show()

# %%
#now we will seperate, static and dynamic activities
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=5,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Static Activities", xy=(-0.960,12), xytext=(-0.5, 15), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Dynamic Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).

# %%
#for concise visualization purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Static Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.08, -0.2, 0.1, 20])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Dynamic Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).

# %%
#to elaborate the seperation of static and dynamic activities we will plot some plots
#1 Magnitude of accleration
plt.figure(figsize=(7,5))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Magnitude of Accelaration Mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %%
#2 Position of gravitational accelaration components 
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravitational Mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %%
#Dimensionality Reduction using t-SNE (T-Distributed Stochastic Neighbor Embedding)
#performing t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.007s...
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.934s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597464
# [t-SNE] Computed conditional probabilities in 0.030s
# [t-SNE] Iteration 50: error = 124.8320312, gradient norm = 0.0260401 (50 iterations in 1.127s)
# [t-SNE] Iteration 100: error = 107.5112686, gradient norm = 0.0278401 (50 iterations in 0.968s)
# [t-SNE] Iteration 150: error = 101.1291580, gradient norm = 0.0217426 (50 iterations in 0.618s)
# [t-SNE] Iteration 200: error = 97.5664902, gradient norm = 0.0186074 (50 iterations in 0.715s)
# [t-SNE] Iteration 250: error = 95.1880569, gradient norm = 0.0133800 (50 iterations in 0.623s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.188057
# [t-SNE] Iteration 300: error = 4.1176357, gradient norm = 0.0015626 (50 iterations in 0.609s)
# [t-SNE] Iteration 350: error = 3.2056746, gradient norm = 0.0010120 (50 iterations in 0.730s)
# [t-SNE] Iteration 400: error = 2.7756002, gradient norm = 0.0007064 (50 iterations in 0.809s)
# [t-SNE] Iteration 450: error = 2.5119271, gradient norm = 0.0005674 (50 iterations in 0.695s)
# [t-SNE] Iteration 500: error = 2.3288567, gradient norm = 0.0004784 (50 iterations in 0.761s)
# [t-SNE] Iteration 550: error = 2.1910498, gradient norm = 0.0004187 (50 iterations in 0.664s)
# [t-SNE] Iteration 600: error = 2.0819757, gradient norm = 0.0003696 (50 iterations in 0.653s)
# [t-SNE] Iteration 650: error = 1.9924431, gradient norm = 0.0003285 (50 iterations in 0.709s)
# [t-SNE] Iteration 700: error = 1.9169812, gradient norm = 0.0002994 (50 iterations in 0.685s)
# [t-SNE] Iteration 750: error = 1.8519760, gradient norm = 0.0002772 (50 iterations in 0.693s)
# [t-SNE] Iteration 800: error = 1.7951441, gradient norm = 0.0002598 (50 iterations in 0.702s)
# [t-SNE] Iteration 850: error = 1.7451248, gradient norm = 0.0002402 (50 iterations in 0.756s)
# [t-SNE] Iteration 900: error = 1.7004344, gradient norm = 0.0002243 (50 iterations in 0.687s)
# [t-SNE] Iteration 950: error = 1.6603036, gradient norm = 0.0002130 (50 iterations in 0.665s)
# [t-SNE] Iteration 1000: error = 1.6239532, gradient norm = 0.0001999 (50 iterations in 0.647s)
# [t-SNE] KL divergence after 1000 iterations: 1.623953
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.179s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.036s
# [t-SNE] Iteration 50: error = 114.0576324, gradient norm = 0.0218382 (50 iterations in 1.187s)
# [t-SNE] Iteration 100: error = 97.5845947, gradient norm = 0.0186292 (50 iterations in 0.786s)
# [t-SNE] Iteration 150: error = 93.2269669, gradient norm = 0.0090967 (50 iterations in 0.686s)
# [t-SNE] Iteration 200: error = 91.2627945, gradient norm = 0.0066283 (50 iterations in 0.731s)
# [t-SNE] Iteration 250: error = 90.0831528, gradient norm = 0.0051120 (50 iterations in 0.686s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.083153
# [t-SNE] Iteration 300: error = 3.5776885, gradient norm = 0.0014652 (50 iterations in 0.677s)
# [t-SNE] Iteration 350: error = 2.8179207, gradient norm = 0.0007498 (50 iterations in 0.682s)
# [t-SNE] Iteration 400: error = 2.4362178, gradient norm = 0.0005271 (50 iterations in 0.668s)
# [t-SNE] Iteration 450: error = 2.2179108, gradient norm = 0.0004080 (50 iterations in 0.677s)
# [t-SNE] Iteration 500: error = 2.0725942, gradient norm = 0.0003331 (50 iterations in 0.710s)
# [t-SNE] Iteration 550: error = 1.9671576, gradient norm = 0.0002836 (50 iterations in 0.687s)
# [t-SNE] Iteration 600: error = 1.8859148, gradient norm = 0.0002461 (50 iterations in 0.701s)
# [t-SNE] Iteration 650: error = 1.8204945, gradient norm = 0.0002216 (50 iterations in 0.704s)
# [t-SNE] Iteration 700: error = 1.7668513, gradient norm = 0.0001970 (50 iterations in 0.696s)
# [t-SNE] Iteration 750: error = 1.7214470, gradient norm = 0.0001807 (50 iterations in 0.711s)
# [t-SNE] Iteration 800: error = 1.6824667, gradient norm = 0.0001656 (50 iterations in 0.748s)
# [t-SNE] Iteration 850: error = 1.6485238, gradient norm = 0.0001518 (50 iterations in 0.739s)
# [t-SNE] Iteration 900: error = 1.6187179, gradient norm = 0.0001433 (50 iterations in 0.733s)
# [t-SNE] Iteration 950: error = 1.5923069, gradient norm = 0.0001327 (50 iterations in 0.731s)
# [t-SNE] Iteration 1000: error = 1.5682607, gradient norm = 0.0001262 (50 iterations in 0.733s)
# [t-SNE] KL divergence after 1000 iterations: 1.568261
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 7.450s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.598s
# [t-SNE] Iteration 50: error = 105.8401108, gradient norm = 0.0192729 (50 iterations in 9.155s)
# [t-SNE] Iteration 100: error = 90.8994141, gradient norm = 0.0103784 (50 iterations in 0.856s)
# [t-SNE] Iteration 150: error = 87.5937500, gradient norm = 0.0056373 (50 iterations in 0.778s)
# [t-SNE] Iteration 200: error = 86.3195724, gradient norm = 0.0051136 (50 iterations in 0.677s)
# [t-SNE] Iteration 250: error = 85.5725098, gradient norm = 0.0030194 (50 iterations in 0.682s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.572510
# [t-SNE] Iteration 300: error = 3.1358373, gradient norm = 0.0013858 (50 iterations in 0.685s)
# [t-SNE] Iteration 350: error = 2.4948001, gradient norm = 0.0006476 (50 iterations in 0.751s)
# [t-SNE] Iteration 400: error = 2.1749160, gradient norm = 0.0004230 (50 iterations in 0.697s)
# [t-SNE] Iteration 450: error = 1.9903141, gradient norm = 0.0003157 (50 iterations in 0.713s)
# [t-SNE] Iteration 500: error = 1.8725460, gradient norm = 0.0002495 (50 iterations in 0.715s)
# [t-SNE] Iteration 550: error = 1.7893839, gradient norm = 0.0002100 (50 iterations in 0.722s)
# [t-SNE] Iteration 600: error = 1.7265322, gradient norm = 0.0001819 (50 iterations in 0.721s)
# [t-SNE] Iteration 650: error = 1.6776911, gradient norm = 0.0001609 (50 iterations in 0.717s)
# [t-SNE] Iteration 700: error = 1.6382606, gradient norm = 0.0001443 (50 iterations in 0.744s)
# [t-SNE] Iteration 750: error = 1.6056709, gradient norm = 0.0001304 (50 iterations in 0.701s)
# [t-SNE] Iteration 800: error = 1.5782347, gradient norm = 0.0001189 (50 iterations in 0.717s)
# [t-SNE] Iteration 850: error = 1.5546629, gradient norm = 0.0001097 (50 iterations in 0.726s)
# [t-SNE] Iteration 900: error = 1.5340538, gradient norm = 0.0001042 (50 iterations in 0.710s)
# [t-SNE] Iteration 950: error = 1.5161364, gradient norm = 0.0000992 (50 iterations in 0.710s)
# [t-SNE] Iteration 1000: error = 1.5005287, gradient norm = 0.0000912 (50 iterations in 0.715s)
# [t-SNE] KL divergence after 1000 iterations: 1.500529
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.185s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.124s
# [t-SNE] Iteration 50: error = 97.7908325, gradient norm = 0.0153622 (50 iterations in 1.426s)
# [t-SNE] Iteration 100: error = 84.4705963, gradient norm = 0.0070716 (50 iterations in 1.086s)
# [t-SNE] Iteration 150: error = 82.3467712, gradient norm = 0.0039527 (50 iterations in 0.873s)
# [t-SNE] Iteration 200: error = 81.5417404, gradient norm = 0.0029557 (50 iterations in 0.873s)
# [t-SNE] Iteration 250: error = 81.0895233, gradient norm = 0.0022321 (50 iterations in 1.090s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.089523
# [t-SNE] Iteration 300: error = 2.7086775, gradient norm = 0.0012946 (50 iterations in 0.860s)
# [t-SNE] Iteration 350: error = 2.1764603, gradient norm = 0.0005794 (50 iterations in 0.765s)
# [t-SNE] Iteration 400: error = 1.9240686, gradient norm = 0.0003525 (50 iterations in 0.790s)
# [t-SNE] Iteration 450: error = 1.7756965, gradient norm = 0.0002508 (50 iterations in 0.877s)
# [t-SNE] Iteration 500: error = 1.6807907, gradient norm = 0.0001958 (50 iterations in 0.836s)
# [t-SNE] Iteration 550: error = 1.6158718, gradient norm = 0.0001575 (50 iterations in 0.841s)
# [t-SNE] Iteration 600: error = 1.5688078, gradient norm = 0.0001340 (50 iterations in 0.795s)
# [t-SNE] Iteration 650: error = 1.5330548, gradient norm = 0.0001179 (50 iterations in 0.825s)
# [t-SNE] Iteration 700: error = 1.5050106, gradient norm = 0.0001045 (50 iterations in 0.820s)
# [t-SNE] Iteration 750: error = 1.4831005, gradient norm = 0.0000967 (50 iterations in 0.795s)
# [t-SNE] Iteration 800: error = 1.4655145, gradient norm = 0.0000899 (50 iterations in 0.798s)
# [t-SNE] Iteration 850: error = 1.4513566, gradient norm = 0.0000843 (50 iterations in 0.797s)
# [t-SNE] Iteration 900: error = 1.4396932, gradient norm = 0.0000821 (50 iterations in 0.860s)
# [t-SNE] Iteration 950: error = 1.4301908, gradient norm = 0.0000795 (50 iterations in 0.796s)
# [t-SNE] Iteration 1000: error = 1.4220995, gradient norm = 0.0000758 (50 iterations in 0.802s)
# [t-SNE] KL divergence after 1000 iterations: 1.422099
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# C:\Users\spale\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# [t-SNE] Computed neighbors for 7352 samples in 1.311s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.304s
# [t-SNE] Iteration 50: error = 86.0870667, gradient norm = 0.0238732 (50 iterations in 1.715s)
# [t-SNE] Iteration 100: error = 75.6478500, gradient norm = 0.0040790 (50 iterations in 1.448s)
# [t-SNE] Iteration 150: error = 74.6565170, gradient norm = 0.0021402 (50 iterations in 1.406s)
# [t-SNE] Iteration 200: error = 74.3035583, gradient norm = 0.0015165 (50 iterations in 1.142s)
# [t-SNE] Iteration 250: error = 74.1262512, gradient norm = 0.0013063 (50 iterations in 1.100s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.126251
# [t-SNE] Iteration 300: error = 2.1614900, gradient norm = 0.0012017 (50 iterations in 1.043s)
# [t-SNE] Iteration 350: error = 1.7598927, gradient norm = 0.0004857 (50 iterations in 1.018s)
# [t-SNE] Iteration 400: error = 1.5909736, gradient norm = 0.0002794 (50 iterations in 1.046s)
# [t-SNE] Iteration 450: error = 1.4970533, gradient norm = 0.0001899 (50 iterations in 1.099s)
# [t-SNE] Iteration 500: error = 1.4371276, gradient norm = 0.0001403 (50 iterations in 1.076s)
# [t-SNE] Iteration 550: error = 1.3958747, gradient norm = 0.0001126 (50 iterations in 1.089s)
# [t-SNE] Iteration 600: error = 1.3664137, gradient norm = 0.0000952 (50 iterations in 1.073s)
# [t-SNE] Iteration 650: error = 1.3450437, gradient norm = 0.0000850 (50 iterations in 1.080s)
# [t-SNE] Iteration 700: error = 1.3293294, gradient norm = 0.0000741 (50 iterations in 1.118s)
# [t-SNE] Iteration 750: error = 1.3172030, gradient norm = 0.0000706 (50 iterations in 1.216s)
# [t-SNE] Iteration 800: error = 1.3080008, gradient norm = 0.0000659 (50 iterations in 1.070s)
# [t-SNE] Iteration 850: error = 1.3008970, gradient norm = 0.0000605 (50 iterations in 1.063s)
# [t-SNE] Iteration 900: error = 1.2951100, gradient norm = 0.0000585 (50 iterations in 1.076s)
# [t-SNE] Iteration 950: error = 1.2903471, gradient norm = 0.0000559 (50 iterations in 1.420s)
# [t-SNE] Iteration 1000: error = 1.2860159, gradient norm = 0.0000566 (50 iterations in 1.059s)
# [t-SNE] KL divergence after 1000 iterations: 1.286016
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# We can see from the above t-SNE plots, all the activities except for standing and sitting are completely seeperated

# %% [markdown]
# MACHINE LEARNING ALGORITHMS

# %%
#again importing necessary packages and libraries
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from datetime import datetime

from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
#preparing data for applying machine learning algorithms
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %%
#we need these labels for confusion matrix
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
#we will create a function to plot confusion matrix
plt.rcParams["font.family"] = 'Tahoma'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion Matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#general model specification
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    #now we will store results at various phases
    results = dict()
    
    #the time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X_train, y_train)
    print('Done....!\n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('==> training time:- {}\n'.format(results['training_time']))
    
    
    #now we predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done....!\n')
    results['testing_time'] = test_end_time - test_start_time
    print('==> testing time:- {}\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    #now we calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)

    #now we store accuracy in results
    results['accuracy'] = accuracy
    print('==> Accuracy:- {}\n'.format(accuracy))
   
    
    
    #confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('\n ********Confusion Matrix********')
        print('\n {}'.format(cm))
        
    #now we will plot confusin matrix
    plt.figure(figsize=(6,6))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    #now we will get classification report
    print('****************| Classifiction Report |****************')
    classification_report = metrics.classification_report(y_test, y_pred)
   
    #now we will store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    #now we will add the trained  model to the results
    results['model'] = model
    
    return results

# %%
#now we will create a function to print the gridsearch parameters
def print_grid_search_attributes(model):
    #estimator that gave highest score among all the estimators formed in GridSearch
    print('\n\n==> Best Estimator:')
    print('\t{}\n'.format(model.best_estimator_))


    #parameters that gave best results while performing grid search
    print('\n==> Best parameters:')
    print('\tParameters of best estimator : {}'.format(model.best_params_))


    #number of cross validation splits
    print('\n==> No. of CrossValidation sets:')
    print('\tTotal numbre of cross validation sets: {}'.format(model.n_splits_))


    #average cross validated score of the best estimator, from the Grid Search 
    print('\n==> Best Score:')
    print('\tAverage Cross Validate scores of best estimator : {}'.format(model.best_score_))

# %% [markdown]
# Logistic Regression with gridsearch

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=ConvergenceWarning)

#starting the Grid search
parameters = {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']}
log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=3, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)

#now we observe the attributes of the model 
print_grid_search_attributes(log_reg_grid_results['model'])
# Out:
# training the model..
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Done....!
#
# ==> training time:- 0:00:10.901158
#
# Predicting test data
# Done....!
#
# ==> testing time:- 0:00:00.007001
#
# ==> Accuracy:- 0.9579233118425518
#
#
#  ********Confusion Matrix********
#
#  [[537   0   0   0   0   0]
#  [  0 428  60   0   0   3]
#  [  0  16 516   0   0   0]
#  [  0   0   0 492   3   1]
#  [  0   0   0   4 403  13]
#  [  0   0   0  23   1 447]]
# ****************| Classifiction Report |****************
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.87      0.92       491
#           STANDING       0.90      0.97      0.93       532
#            WALKING       0.95      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.96      0.97       420
#   WALKING_UPSTAIRS       0.96      0.95      0.96       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947
#
#
#
# ==> Best Estimator:
# 	LogisticRegression(C=1)
#
#
# ==> Best parameters:
# 	Parameters of best estimator : {'C': 1, 'penalty': 'l2'}
#
# ==> No. of CrossValidation sets:
# 	Total numbre of cross validation sets: 3
#
# ==> Best Score:
# 	Average Cross Validate scores of best estimator : 0.9375695606680045

# %% [markdown]
# Linear SVC with Grid Search

# %%
parameters = {'C':[0.125, 0.5, 1, 2, 8, 16]}
lr_svc = LinearSVC(tol=0.00005)
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
lr_svc_grid_results = perform_model(lr_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)

#now we will observe the attributes of the model 
print_grid_search_attributes(lr_svc_grid_results['model'])
# Out:
# training the model..
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Done....!
#
# ==> training time:- 0:00:31.080194
#
# Predicting test data
# Done....!
#
# ==> testing time:- 0:00:00.007990
#
# ==> Accuracy:- 0.9667458432304038
#
#
#  ********Confusion Matrix********
#
#  [[537   0   0   0   0   0]
#  [  2 428  58   0   0   3]
#  [  0   9 522   1   0   0]
#  [  0   0   0 496   0   0]
#  [  0   0   0   3 412   5]
#  [  0   0   0  17   0 454]]
# ****************| Classifiction Report |****************
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947
#
#
#
# ==> Best Estimator:
# 	LinearSVC(C=0.5, tol=5e-05)
#
#
# ==> Best parameters:
# 	Parameters of best estimator : {'C': 0.5}
#
# ==> No. of CrossValidation sets:
# 	Total numbre of cross validation sets: 5
#
# ==> Best Score:
# 	Average Cross Validate scores of best estimator : 0.9422003634900594

# %% [markdown]
# Kernel SVM with Grid Search

# %%
parameters = {'C':[2,8,16],\
              'gamma': [ 0.0078125, 0.125, 2]}
rbf_svm = SVC(kernel='rbf')
rbf_svm_grid = GridSearchCV(rbf_svm,param_grid=parameters, n_jobs=-1)
rbf_svm_grid_results = perform_model(rbf_svm_grid, X_train, y_train, X_test, y_test, class_labels=labels)

#now we will observe the attributes of the model 
print_grid_search_attributes(rbf_svm_grid_results['model'])
# Out:
# training the model..
# Done....!
#
# ==> training time:- 0:04:02.681684
#
# Predicting test data
# Done....!
#
# ==> testing time:- 0:00:01.345315
#
# ==> Accuracy:- 0.9626739056667798
#
#
#  ********Confusion Matrix********
#
#  [[537   0   0   0   0   0]
#  [  0 441  48   0   0   2]
#  [  0  12 520   0   0   0]
#  [  0   0   0 489   2   5]
#  [  0   0   0   4 397  19]
#  [  0   0   0  17   1 453]]
# ****************| Classifiction Report |****************
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.90      0.93       491
#           STANDING       0.92      0.98      0.95       532
#            WALKING       0.96      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.95      0.97       420
#   WALKING_UPSTAIRS       0.95      0.96      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947
#
#
#
# ==> Best Estimator:
# 	SVC(C=16, gamma=0.0078125)
#
#
# ==> Best parameters:
# 	Parameters of best estimator : {'C': 16, 'gamma': 0.0078125}
#
# ==> No. of CrossValidation sets:
# 	Total numbre of cross validation sets: 5
#
# ==> Best Score:
# 	Average Cross Validate scores of best estimator : 0.9447834551903698

# %% [markdown]
# Decision Trees with Grid Search

# %%
parameters = {'max_depth':np.arange(3,10,2)}
dt = DecisionTreeClassifier()
dt_grid = GridSearchCV(dt,param_grid=parameters, n_jobs=-1)
dt_grid_results = perform_model(dt_grid, X_train, y_train, X_test, y_test, class_labels=labels)

#now we will observe the attributes of the model 
print_grid_search_attributes(dt_grid_results['model'])
# Out:
# training the model..
# Done....!
#
# ==> training time:- 0:00:08.902485
#
# Predicting test data
# Done....!
#
# ==> testing time:- 0:00:00.007019
#
# ==> Accuracy:- 0.838140481845945
#
#
#  ********Confusion Matrix********
#
#  [[537   0   0   0   0   0]
#  [  0 399  92   0   0   0]
#  [  0 113 419   0   0   0]
#  [  0   0   0 470  10  16]
#  [  0   0   0  49 266 105]
#  [  0   0   0  86   6 379]]
# ****************| Classifiction Report |****************
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.78      0.81      0.80       491
#           STANDING       0.82      0.79      0.80       532
#            WALKING       0.78      0.95      0.85       496
# WALKING_DOWNSTAIRS       0.94      0.63      0.76       420
#   WALKING_UPSTAIRS       0.76      0.80      0.78       471
#
#           accuracy                           0.84      2947
#          macro avg       0.85      0.83      0.83      2947
#       weighted avg       0.85      0.84      0.84      2947
#
#
#
# ==> Best Estimator:
# 	DecisionTreeClassifier(max_depth=5)
#
#
# ==> Best parameters:
# 	Parameters of best estimator : {'max_depth': 5}
#
# ==> No. of CrossValidation sets:
# 	Total numbre of cross validation sets: 5
#
# ==> Best Score:
# 	Average Cross Validate scores of best estimator : 0.8498404065909165

# %% [markdown]
# Random Forest Classifier with Grid Search

# %%
params = {'n_estimators': np.arange(10,201,20), 'max_depth':np.arange(3,15,2)}
rfc = RandomForestClassifier()
rfc_grid = GridSearchCV(rfc, param_grid=params, n_jobs=-1)
rfc_grid_results = perform_model(rfc_grid, X_train, y_train, X_test, y_test, class_labels=labels)

#now we will observe the attributes of the model 
print_grid_search_attributes(rfc_grid_results['model'])
# Out:
# training the model..
# Done....!
#
# ==> training time:- 0:05:11.268757
#
# Predicting test data
# Done....!
#
# ==> testing time:- 0:00:00.056025
#
# ==> Accuracy:- 0.9178825924669155
#
#
#  ********Confusion Matrix********
#
#  [[537   0   0   0   0   0]
#  [  0 432  59   0   0   0]
#  [  0  46 486   0   0   0]
#  [  0   0   0 479  10   7]
#  [  0   0   0  29 346  45]
#  [  0   0   0  40   6 425]]
# ****************| Classifiction Report |****************
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.90      0.88      0.89       491
#           STANDING       0.89      0.91      0.90       532
#            WALKING       0.87      0.97      0.92       496
# WALKING_DOWNSTAIRS       0.96      0.82      0.88       420
#   WALKING_UPSTAIRS       0.89      0.90      0.90       471
#
#           accuracy                           0.92      2947
#          macro avg       0.92      0.91      0.92      2947
#       weighted avg       0.92      0.92      0.92      2947
#
#
#
# ==> Best Estimator:
# 	RandomForestClassifier(max_depth=9, n_estimators=150)
#
#
# ==> Best parameters:
# 	Parameters of best estimator : {'max_depth': 9, 'n_estimators': 150}
#
# ==> No. of CrossValidation sets:
# 	Total numbre of cross validation sets: 5
#
# ==> Best Score:
# 	Average Cross Validate scores of best estimator : 0.9215230510967134

# %% [markdown]
# Comparing all Machine Learning models with each other

# %%
# ***************************** Print Accuracy and Error ******************************

print('\n                     Accuracy     Error')
print('                     ----------   --------')
print('Logistic Regression : {:.04}%       {:.04}%'.format(log_reg_grid_results['accuracy'] * 100,\
                                                  100-(log_reg_grid_results['accuracy'] * 100)))

print('Linear SVC          : {:.04}%       {:.04}% '.format(lr_svc_grid_results['accuracy'] * 100,\
                                                        100-(lr_svc_grid_results['accuracy'] * 100)))

print('rbf SVM classifier  : {:.04}%       {:.04}% '.format(rbf_svm_grid_results['accuracy'] * 100,\
                                                          100-(rbf_svm_grid_results['accuracy'] * 100)))

print('DecisionTree        : {:.04}%       {:.04}% '.format(dt_grid_results['accuracy'] * 100,\
                                                        100-(dt_grid_results['accuracy'] * 100)))

print('Random Forest       : {:.04}%       {:.04}% '.format(rfc_grid_results['accuracy'] * 100,\
                                                           100-(rfc_grid_results['accuracy'] * 100)))
# Out:
#                      Accuracy     Error
#                      ----------   --------
# Logistic Regression : 95.79%       4.208%
# Linear SVC          : 96.67%       3.325%
# rbf SVM classifier  : 96.27%       3.733%
# DecisionTree        : 83.81%       16.19%
# Random Forest       : 91.79%       8.212%

# %% [markdown]
# DEEP NEURAL NETWORKS IMPLEMENTATION

# %%
#for Deep Learning implementation, we will use Keras
#importing all the necessasry libraries
from keras import backend as K
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout
from keras.layers import BatchNormalization
from keras.regularizers import L1L2

# %%
#activities are the class labels
#it iss a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# %%
#preparing data for implementation
#data directory
DATADIR = 'UCI_HAR_Dataset'

#saw data sensor signals are used for deep learning implementation
#signals are from Accelerometer and Gyroscope
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
    ]

# %%
#we create a function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

#we create a function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = f'UCI HAR Dataset/{subset}/Inertial Signals/{signal}_{subset}.txt'
        signals_data.append(
            _read_csv(filename).to_numpy()
        ) 

    #we use transpose to change the dimensionality of the output,
    #aggregating the signals by combination of sample/timestep.
    #resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
def load_y(subset):

    filename = f'UCI HAR Dataset/{subset}/y_{subset}.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).to_numpy()

# %%
def load_data():
    
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test

# %%
#importing tensorflow
np.random.seed(50)
import tensorflow as tf
tf.random.set_seed(50)

# %%
#initializing parameters
epochs = 30
batch_size = 32
n_hidden = 32

# %%
#we create a function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
#loading the train and test data
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %% [markdown]
# Defining Architecture of LSTM with 1 layer

# %%
#initiliazing the sequential model
model = Sequential()

#configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))

#adding a dropout layer
model.add(Dropout(0.7))

#adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                5376
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 6)                 198
#
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling the model
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
#training the model
history = model.fit(X_train, Y_train, epochs=30, batch_size=32, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/30
# 230/230 [==============================] - 9s 31ms/step - loss: 1.3930 - accuracy: 0.4075 - val_loss: 1.1649 - val_accuracy: 0.5008
# Epoch 2/30
# 230/230 [==============================] - 7s 28ms/step - loss: 1.0282 - accuracy: 0.5592 - val_loss: 0.8491 - val_accuracy: 0.6216
# Epoch 3/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.8416 - accuracy: 0.6144 - val_loss: 0.8415 - val_accuracy: 0.5962
# Epoch 4/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.7799 - accuracy: 0.6412 - val_loss: 0.7491 - val_accuracy: 0.6566
# Epoch 5/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.7416 - accuracy: 0.6544 - val_loss: 0.7334 - val_accuracy: 0.6827
# Epoch 6/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.7388 - accuracy: 0.6534 - val_loss: 0.7015 - val_accuracy: 0.7184
# Epoch 7/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.7782 - accuracy: 0.6711 - val_loss: 0.6776 - val_accuracy: 0.7353
# Epoch 8/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.6298 - accuracy: 0.7320 - val_loss: 0.6388 - val_accuracy: 0.7445
# Epoch 9/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.5928 - accuracy: 0.7526 - val_loss: 0.5813 - val_accuracy: 0.7699
# Epoch 10/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.6222 - accuracy: 0.7316 - val_loss: 0.6064 - val_accuracy: 0.7370
# Epoch 11/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.5306 - accuracy: 0.7700 - val_loss: 0.5664 - val_accuracy: 0.7696
# Epoch 12/30
# 230/230 [==============================] - 7s 29ms/step - loss: 0.6542 - accuracy: 0.7594 - val_loss: 1.0754 - val_accuracy: 0.6569
# Epoch 13/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.6369 - accuracy: 0.7643 - val_loss: 0.5441 - val_accuracy: 0.7828
# Epoch 14/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.5096 - accuracy: 0.8118 - val_loss: 0.5317 - val_accuracy: 0.8076
# Epoch 15/30
# 230/230 [==============================] - 7s 30ms/step - loss: 0.6830 - accuracy: 0.7490 - val_loss: 1.5396 - val_accuracy: 0.5144
# Epoch 16/30
# 230/230 [==============================] - 7s 30ms/step - loss: 0.6832 - accuracy: 0.7315 - val_loss: 0.5924 - val_accuracy: 0.8168
# Epoch 17/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.4946 - accuracy: 0.8373 - val_loss: 0.5581 - val_accuracy: 0.8521
# Epoch 18/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.4369 - accuracy: 0.8594 - val_loss: 0.5450 - val_accuracy: 0.8476
# Epoch 19/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.3987 - accuracy: 0.8770 - val_loss: 0.4739 - val_accuracy: 0.8592
# Epoch 20/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.3615 - accuracy: 0.8832 - val_loss: 0.4715 - val_accuracy: 0.8588
# Epoch 21/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.3409 - accuracy: 0.8951 - val_loss: 0.4721 - val_accuracy: 0.8673
# Epoch 22/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.3224 - accuracy: 0.8984 - val_loss: 0.5374 - val_accuracy: 0.8565
# Epoch 23/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.3094 - accuracy: 0.9011 - val_loss: 0.4952 - val_accuracy: 0.8704
# Epoch 24/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.4124 - accuracy: 0.8834 - val_loss: 0.5185 - val_accuracy: 0.8694
# Epoch 25/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.2934 - accuracy: 0.9115 - val_loss: 0.4736 - val_accuracy: 0.8761
# Epoch 26/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.2566 - accuracy: 0.9268 - val_loss: 1.1659 - val_accuracy: 0.7441
# Epoch 27/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.2808 - accuracy: 0.9120 - val_loss: 0.4988 - val_accuracy: 0.8775
# Epoch 28/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.2620 - accuracy: 0.9199 - val_loss: 0.4528 - val_accuracy: 0.8670
# Epoch 29/30
# 230/230 [==============================] - 6s 28ms/step - loss: 0.3484 - accuracy: 0.8923 - val_loss: 0.4356 - val_accuracy: 0.8677
# Epoch 30/30
# 230/230 [==============================] - 7s 28ms/step - loss: 0.2579 - accuracy: 0.9184 - val_loss: 0.5079 - val_accuracy: 0.8677

# %%
score = model.evaluate(X_test, Y_test)

print("\n   crossentropy  ||   accuracy ")
print("  ____________________________________")
print(score)
# Out:
# 93/93 [==============================] - 1s 8ms/step - loss: 0.5079 - accuracy: 0.8677
#
#    crossentropy  ||   accuracy
#   ____________________________________
# [0.5079137682914734, 0.8676620125770569]

# %% [markdown]
# 2- Layer LSTM Model with hyperparameter tuning

# %%
#initializing parameters
n_epochs = 30
n_batch = 32
n_classes = _count_classes(Y_train)

#bias regularizer value - we will use elasticnet
reg = L1L2(0.01, 0.01)

# %%
#model implementation
model = Sequential()
model.add(LSTM(48, input_shape=(timesteps, input_dim), return_sequences=True,bias_regularizer=reg ))
model.add(BatchNormalization())
model.add(Dropout(0.50))
model.add(LSTM(32))
model.add(Dropout(0.50))
model.add(Dense(n_classes, activation='sigmoid'))
print("Model Summary: ")
model.summary()
# Out:
# Model Summary:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 128, 48)           11136
#
#  batch_normalization_3 (Batc  (None, 128, 48)          192
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 128, 48)           0
#
#  lstm_8 (LSTM)               (None, 32)                10368
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 21,894
# Trainable params: 21,798
# Non-trainable params: 96
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
#training the model
model.fit(X_train, Y_train, batch_size=n_batch, validation_data=(X_test, Y_test), epochs=n_epochs)
# Out:
# Epoch 1/30
# 230/230 [==============================] - 20s 68ms/step - loss: 1.7816 - accuracy: 0.6549 - val_loss: 1.5831 - val_accuracy: 0.6447
# Epoch 2/30
# 230/230 [==============================] - 15s 66ms/step - loss: 1.0360 - accuracy: 0.8473 - val_loss: 1.0465 - val_accuracy: 0.8079
# Epoch 3/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.6713 - accuracy: 0.9155 - val_loss: 0.6611 - val_accuracy: 0.8778
# Epoch 4/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.5184 - accuracy: 0.9123 - val_loss: 0.8343 - val_accuracy: 0.7879
# Epoch 5/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.3632 - accuracy: 0.9306 - val_loss: 0.4829 - val_accuracy: 0.8880
# Epoch 6/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.2728 - accuracy: 0.9320 - val_loss: 0.4067 - val_accuracy: 0.8894
# Epoch 7/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1961 - accuracy: 0.9423 - val_loss: 0.4562 - val_accuracy: 0.8765
# Epoch 8/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1742 - accuracy: 0.9419 - val_loss: 0.2970 - val_accuracy: 0.9033
# Epoch 9/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.2723 - accuracy: 0.9124 - val_loss: 0.3563 - val_accuracy: 0.8989
# Epoch 10/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1990 - accuracy: 0.9295 - val_loss: 0.2865 - val_accuracy: 0.9111
# Epoch 11/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1814 - accuracy: 0.9392 - val_loss: 0.3790 - val_accuracy: 0.9053
# Epoch 12/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1628 - accuracy: 0.9422 - val_loss: 0.3520 - val_accuracy: 0.9009
# Epoch 13/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1676 - accuracy: 0.9370 - val_loss: 0.3019 - val_accuracy: 0.8996
# Epoch 14/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1547 - accuracy: 0.9400 - val_loss: 0.3014 - val_accuracy: 0.9013
# Epoch 15/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1500 - accuracy: 0.9475 - val_loss: 0.3632 - val_accuracy: 0.9067
# Epoch 16/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1541 - accuracy: 0.9455 - val_loss: 0.3202 - val_accuracy: 0.8985
# Epoch 17/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1395 - accuracy: 0.9465 - val_loss: 0.3009 - val_accuracy: 0.9046
# Epoch 18/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1408 - accuracy: 0.9446 - val_loss: 0.2482 - val_accuracy: 0.9189
# Epoch 19/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1602 - accuracy: 0.9425 - val_loss: 0.2740 - val_accuracy: 0.9006
# Epoch 20/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1401 - accuracy: 0.9440 - val_loss: 0.2078 - val_accuracy: 0.9169
# Epoch 21/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1328 - accuracy: 0.9468 - val_loss: 0.3107 - val_accuracy: 0.9026
# Epoch 22/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1358 - accuracy: 0.9498 - val_loss: 0.2207 - val_accuracy: 0.9118
# Epoch 23/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1376 - accuracy: 0.9449 - val_loss: 0.3109 - val_accuracy: 0.9094
# Epoch 24/30
# 230/230 [==============================] - 16s 67ms/step - loss: 0.1265 - accuracy: 0.9474 - val_loss: 0.3335 - val_accuracy: 0.9074
# Epoch 25/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1391 - accuracy: 0.9490 - val_loss: 0.5032 - val_accuracy: 0.8548
# Epoch 26/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1348 - accuracy: 0.9495 - val_loss: 0.2950 - val_accuracy: 0.9114
# Epoch 27/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1242 - accuracy: 0.9509 - val_loss: 0.3065 - val_accuracy: 0.8948
# Epoch 28/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.2567 - accuracy: 0.9173 - val_loss: 0.4480 - val_accuracy: 0.8605
# Epoch 29/30
# 230/230 [==============================] - 15s 67ms/step - loss: 0.1622 - accuracy: 0.9433 - val_loss: 0.3303 - val_accuracy: 0.9165
# Epoch 30/30
# 230/230 [==============================] - 15s 66ms/step - loss: 0.1516 - accuracy: 0.9448 - val_loss: 0.3764 - val_accuracy: 0.8884

# %%
score = model.evaluate(X_test, Y_test)

print("\n   crossentropy  ||   accuracy ")
print("  ____________________________________")
print(score)
# Out:
# 93/93 [==============================] - 2s 18ms/step - loss: 0.3764 - accuracy: 0.8884
#
#    crossentropy  ||   accuracy
#   ____________________________________
# [0.37639862298965454, 0.8883610367774963]

# %% [markdown]
# 2 -Layer LSTM with more Hyperparameter tuning

# %%
#model implementation
model = Sequential()
model.add(LSTM(64, input_shape=(timesteps, input_dim), return_sequences=True, bias_regularizer=reg))
model.add(BatchNormalization())
model.add(Dropout(0.50))
model.add(LSTM(48))
model.add(Dropout(0.50))
model.add(Dense(n_classes, activation='sigmoid'))
print("Model Summary: ")
model.summary()
# Out:
# Model Summary:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 128, 64)           18944
#
#  batch_normalization_1 (Batc  (None, 128, 64)          256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128, 64)           0
#
#  lstm_4 (LSTM)               (None, 48)                21696
#
#  dropout_4 (Dropout)         (None, 48)                0
#
#  dense_2 (Dense)             (None, 6)                 294
#
# =================================================================
# Total params: 41,190
# Trainable params: 41,062
# Non-trainable params: 128
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
#training the model
history = model.fit(X_train, Y_train, batch_size=32, validation_data=(X_test, Y_test), epochs=30)
# Out:
# Epoch 1/30
# 230/230 [==============================] - 22s 80ms/step - loss: 1.8526 - accuracy: 0.7179 - val_loss: 2.1322 - val_accuracy: 0.5334
# Epoch 2/30
# 230/230 [==============================] - 17s 74ms/step - loss: 1.0785 - accuracy: 0.8966 - val_loss: 0.9582 - val_accuracy: 0.8856
# Epoch 3/30
# 230/230 [==============================] - 20s 86ms/step - loss: 0.7314 - accuracy: 0.9282 - val_loss: 0.8505 - val_accuracy: 0.8212
# Epoch 4/30
# 230/230 [==============================] - 20s 86ms/step - loss: 0.5213 - accuracy: 0.9256 - val_loss: 1.5534 - val_accuracy: 0.5718
# Epoch 5/30
# 230/230 [==============================] - 20s 86ms/step - loss: 0.3643 - accuracy: 0.9317 - val_loss: 0.3819 - val_accuracy: 0.9087
# Epoch 6/30
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2312 - accuracy: 0.9377 - val_loss: 0.2857 - val_accuracy: 0.9125
# Epoch 7/30
# 230/230 [==============================] - 18s 78ms/step - loss: 0.1563 - accuracy: 0.9446 - val_loss: 0.2874 - val_accuracy: 0.9158
# Epoch 8/30
# 230/230 [==============================] - 18s 77ms/step - loss: 0.1507 - accuracy: 0.9449 - val_loss: 0.2070 - val_accuracy: 0.9257
# Epoch 9/30
# 230/230 [==============================] - 18s 76ms/step - loss: 0.1456 - accuracy: 0.9456 - val_loss: 0.2310 - val_accuracy: 0.9131
# Epoch 10/30
# 230/230 [==============================] - 18s 77ms/step - loss: 0.1347 - accuracy: 0.9463 - val_loss: 0.2136 - val_accuracy: 0.9182
# Epoch 11/30
# 230/230 [==============================] - 18s 77ms/step - loss: 0.1275 - accuracy: 0.9480 - val_loss: 0.2097 - val_accuracy: 0.9260
# Epoch 12/30
# 230/230 [==============================] - 18s 77ms/step - loss: 0.1817 - accuracy: 0.9358 - val_loss: 0.7688 - val_accuracy: 0.7377
# Epoch 13/30
# 230/230 [==============================] - 18s 77ms/step - loss: 0.1565 - accuracy: 0.9410 - val_loss: 0.3180 - val_accuracy: 0.9063
# Epoch 14/30
# 230/230 [==============================] - 18s 79ms/step - loss: 0.1519 - accuracy: 0.9430 - val_loss: 0.3513 - val_accuracy: 0.9040
# Epoch 15/30
# 230/230 [==============================] - 18s 79ms/step - loss: 0.1394 - accuracy: 0.9440 - val_loss: 0.2664 - val_accuracy: 0.9237
# Epoch 16/30
# 230/230 [==============================] - 18s 77ms/step - loss: 0.1332 - accuracy: 0.9468 - val_loss: 0.2944 - val_accuracy: 0.9301
# Epoch 17/30
# 230/230 [==============================] - 18s 78ms/step - loss: 0.1244 - accuracy: 0.9487 - val_loss: 0.3277 - val_accuracy: 0.9192
# Epoch 18/30
# 230/230 [==============================] - 18s 80ms/step - loss: 0.1280 - accuracy: 0.9471 - val_loss: 0.2804 - val_accuracy: 0.9199
# Epoch 19/30
# 230/230 [==============================] - 18s 78ms/step - loss: 0.1219 - accuracy: 0.9482 - val_loss: 0.2713 - val_accuracy: 0.9253
# Epoch 20/30
# 230/230 [==============================] - 20s 87ms/step - loss: 0.1220 - accuracy: 0.9484 - val_loss: 0.3263 - val_accuracy: 0.9087
# Epoch 21/30
# 230/230 [==============================] - 19s 84ms/step - loss: 0.1448 - accuracy: 0.9421 - val_loss: 0.2260 - val_accuracy: 0.9226
# Epoch 22/30
# 230/230 [==============================] - 18s 78ms/step - loss: 0.1343 - accuracy: 0.9457 - val_loss: 0.1946 - val_accuracy: 0.9209
# Epoch 23/30
# 230/230 [==============================] - 18s 78ms/step - loss: 0.1260 - accuracy: 0.9484 - val_loss: 0.1938 - val_accuracy: 0.9298
# Epoch 24/30
# 230/230 [==============================] - 18s 77ms/step - loss: 0.1275 - accuracy: 0.9471 - val_loss: 0.2276 - val_accuracy: 0.9240
# Epoch 25/30
# 230/230 [==============================] - 17s 74ms/step - loss: 0.1167 - accuracy: 0.9531 - val_loss: 0.2974 - val_accuracy: 0.8958
# Epoch 26/30
# 230/230 [==============================] - 18s 79ms/step - loss: 0.1443 - accuracy: 0.9470 - val_loss: 0.2735 - val_accuracy: 0.9175
# Epoch 27/30
# 230/230 [==============================] - 17s 75ms/step - loss: 0.1579 - accuracy: 0.9406 - val_loss: 0.5185 - val_accuracy: 0.8561
# Epoch 28/30
# 230/230 [==============================] - 17s 75ms/step - loss: 0.1616 - accuracy: 0.9421 - val_loss: 0.2835 - val_accuracy: 0.9138
# Epoch 29/30
# 230/230 [==============================] - 17s 74ms/step - loss: 0.1243 - accuracy: 0.9510 - val_loss: 0.2936 - val_accuracy: 0.9165
# Epoch 30/30
# 230/230 [==============================] - 17s 75ms/step - loss: 0.1208 - accuracy: 0.9520 - val_loss: 0.3417 - val_accuracy: 0.9213

# %%
score = model.evaluate(X_test, Y_test)

print("\n   crossentropy  ||   accuracy ")
print("  ____________________________________")
print(score)
# Out:
# 93/93 [==============================] - 2s 21ms/step - loss: 0.3417 - accuracy: 0.9213
#
#    crossentropy  ||   accuracy
#   ____________________________________
# [0.3416588008403778, 0.9212758541107178]

# %% [markdown]
# Comparing all models and Conclusion

# %% [markdown]
# Comapring Machine Learning Models

# %%
#importing prettytable
# %pip install prettytable
import prettytable
from prettytable import PrettyTable
# Out:
# Collecting prettytable
#   Downloading prettytable-3.3.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: wcwidth in c:\users\spale\appdata\roaming\python\python39\site-packages (from prettytable) (0.2.5)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.3.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\spale\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
ptable1 = PrettyTable()
ptable1.title = " Model Comparision "
ptable1.field_names = ['Model Name', 'Accuracy']

print("\n\n ********** Machine Learning Model Comparision ************")
ptable1.add_row(["Logistic Regression","95.79%"])
ptable1.add_row(["Linear SVC  ","96.67%"])
ptable1.add_row(["rbf SVM classifier","96.27%"])
ptable1.add_row(["DecisionTree","87.44%"])
ptable1.add_row(["Random Forest","91.89%"])

print(ptable1)
# *****************************************************************

ptable2 = PrettyTable()
ptable2.title = " Model Comparision "
ptable2.field_names = ['Model Name', 'categorical_crossentropy', 'Accuracy']

print("\n\n ********************************* Deep Learning LSTM Model Comparision ***********************************")
ptable2.add_row(["LSTM With 1_Layer(neurons:32)","0.4785", "0.9195"])
ptable2.add_row(["LSTM With 2_Layer(neurons:48, neurons:32)","0.4", "0.902"])
ptable2.add_row(["LSTM With 2_Layer(neurons:64, neurons:48)","0.34", "0.9213"])

print(ptable2)
# Out:
#  ********** Machine Learning Model Comparision ************
# +--------------------------------+
# |       Model Comparision        |
# +---------------------+----------+
# |      Model Name     | Accuracy |
# +---------------------+----------+
# | Logistic Regression |  95.79%  |
# |     Linear SVC      |  96.67%  |
# |  rbf SVM classifier |  96.27%  |
# |     DecisionTree    |  87.44%  |
# |    Random Forest    |  91.89%  |
# +---------------------+----------+
#
#
#  ********************************* Deep Learning LSTM Model Comparision ***********************************
# +---------------------------------------------------------------------------------+
# |                                Model Comparision                                |
# +-------------------------------------------+--------------------------+----------+
# |                 Model Name                | categorical_crossentropy | Accuracy |
# +-------------------------------------------+--------------------------+----------+
# |       LSTM With 1_Layer(neurons:32)       |          0.4785          |  0.9195  |
# | LSTM With 2_Layer(neurons:48, neurons:32) |           0.4            |  0.902   |
# | LSTM With 2_Layer(neurons:64, neurons:48) |           0.34           |  0.9213  |
# +-------------------------------------------+--------------------------+----------+
